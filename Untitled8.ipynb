# %%
import json
with open('twitterData.txt','r') as f:
    twtr_auth = json.load(f)

from twitter import *
# Loading my authentication tokens
#with open('auth_dict','r') as f:
#    twtr_auth = json.load(f)

# To make it more readable, lets store
# the OAuth credentials in strings first.
CONSUMER_KEY = twtr_auth['API_keys']
CONSUMER_SECRET = twtr_auth['API_secret_key']
OAUTH_TOKEN = twtr_auth['Access_token']
OAUTH_TOKEN_SECRET = twtr_auth['Access_token_secret']
    
# Then, we store the OAuth object in "auth"
auth = OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
# Notice that there are four tokens - you need to create these in the
# Twitter Apps dashboard after you have created your own "app".

# We now create the twitter search object
t= Twitter(auth=auth)

# %%
import pandas as pd
df = pd.DataFrame(columns=['twitterhandle','tweet'])
df.to_csv('data.csv', index=False)

# %%
import tweepy

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
api = tweepy.API(auth)

twitterhandles=['@AOC','@TeamPelosi','@KamalaHarris','@realDonaldTrump','@LindseyGrahamSC','@senatemajldr','@CNN','@FoxNews','@MSNBC']
for screen_name in twitterhandles:
    for status in tweepy.Cursor(api.user_timeline, screen_name, tweet_mode="extended").items():
        if (not status.retweeted) and ('RT @' not in status.full_text):
            df = pd.DataFrame([[screen_name,status.full_text]], columns=['twitterhandle','tweet'])
            with open('data.csv','a',encoding="utf-8") as f:
                df.to_csv(f,header=False, index=False)

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
new_data= pd.read_csv("DATA.csv")

# %%
df1 = new_data.loc[new_data['twitterhandle'] == '@AOC']

# %%
df2 = new_data.loc[new_data['twitterhandle'] == '@TeamPelosi']

# %%
df3 = new_data.loc[new_data['twitterhandle'] == '@KamalaHarris']

# %%
df4 = new_data.loc[new_data['twitterhandle'] == '@realDonaldTrump']
df5 = new_data.loc[new_data['twitterhandle'] == '@LindseyGrahamSC']
df6 = new_data.loc[new_data['twitterhandle'] == '@senatemajldr']
df7 = new_data.loc[new_data['twitterhandle'] == '@CNN']
df8 = new_data.loc[new_data['twitterhandle'] == '@FoxNews']
df9 = new_data.loc[new_data['twitterhandle'] == '@MSNBC']

# %%
text1 = " ".join(review for review in df1.tweet)
text2 = " ".join(review for review in df2.tweet)

# %%
text3 = " ".join(review for review in df3.tweet)
text4 = " ".join(review for review in df4.tweet)
text5 = " ".join(review for review in df5.tweet)
text6 = " ".join(review for review in df6.tweet)
text7 = " ".join(review for review in df7.tweet)
text8 = " ".join(review for review in df8.tweet)
text9 = " ".join(review for review in df9.tweet)

# %%
text3
# Out:
# ''

# %%
#print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 401470 words in the combination of all review.

# %%
stopwords = set(STOPWORDS)
stopwords.update(["https", "RT","co"])

# %%
wordcloud1 = WordCloud(stopwords=stopwords,width=600, height=600, background_color="white").generate(text1)

# %%
wordcloud2=WordCloud(stopwords=stopwords,width=600, height=600, background_color="white").generate(text2)

# %%
wordcloud3=WordCloud(stopwords=stopwords, width=480, height=480,background_color="white").generate(text7)

# %%
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
x="text"+"1"

# %%
text=[text1,text2,text3,text4,text5,text6,text7,text8,text9]

# %%
def topicloud(i, WCmaxWords,WCwidth, WCheight):
    wordcloud = WordCloud(stopwords=stopwords, width=WCwidth,height=WCheight,background_color="white").generate(text[i])
    return wordcloud

# %%
fig = plt.figure()
for i in range(len(text)):
    ax = fig.add_subplot(3,3,i+1)
    wordcloud = topicloud(i,WCmaxWords=100,WCwidth=6000, WCheight=6000)
    ax.imshow(wordcloud)
    ax.axis('off')
